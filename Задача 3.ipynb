# %%
# Исследовать структуру xml-файлов, чтобы произвести парсинг всех данных. 
# В каждом файле содержится информация об одном объекте из случайной предметной области. 
# Полученные данные собрать и записать в json. 
# Выполните также ряд операций с данными:
# отсортируйте значения по одному из доступных полей
# выполните фильтрацию по другому полю (запишите результат отдельно)
# для одного выбранного числового поля посчитайте статистические характеристики (сумма, мин/макс, среднее и т.д.)
# для одного текстового поля посчитайте частоту меток.

# %%
from bs4 import BeautifulSoup
import re
import json
import math
import collections
import pandas as pd

# %%
def handle_file(file_name):
    with open(file_name, encoding = 'utf-8') as file:
        text = ""
        for row in file.readlines():
            text += row
        item = dict()
        site = BeautifulSoup(text, 'xml').star
        for i in site.contents:
            if i.name == "radius":
                item[i.name] = int(i.get_text().strip())
            elif i.name is not None:
                item[i.name] = i.get_text().strip()
        return item

# %%
items = []
for i in range(1,501):
  file_name = f'./3/{i}.xml'
  result = handle_file(file_name)
  items.append(result)
print(items[0:5])
# Out:
# [{'name': 'Акрукс 4218', 'constellation': 'Дева', 'spectral-class': 'J7E', 'radius': 212774202, 'rotation': '613.1 days', 'age': '4.39 billion years', 'distance': '3977846.72 million km', 'absolute-magnitude': '1.51 million km'}, {'name': 'Фомальгаут 3890', 'constellation': 'Близнецы', 'spectral-class': 'X0Z', 'radius': 11659701, 'rotation': '77.02 days', 'age': '1.6 billion years', 'distance': '2109102.94 million km', 'absolute-magnitude': '9.61 million km'}, {'name': 'Альфа Центавра 8441', 'constellation': 'Телец', 'spectral-class': 'Y2I', 'radius': 526007231, 'rotation': '912.07 days', 'age': '2.09 billion years', 'distance': '6729894.03 million km', 'absolute-magnitude': '1.27 million km'}, {'name': 'Фомальгаут 7833', 'constellation': 'Лев', 'spectral-class': 'I3O', 'radius': 116227487, 'rotation': '705.64 days', 'age': '0.43 billion years', 'distance': '6013573.98 million km', 'absolute-magnitude': '4.8 million km'}, {'name': 'Фомалхаут 9781', 'constellation': 'Близнецы', 'spectral-class': 'M8G', 'radius': 558336796, 'rotation': '13.52 days', 'age': '5.45 billion years', 'distance': '9639283.41 million km', 'absolute-magnitude': '8.65 million km'}]

# %%
with open('result_all_63_3.json', 'w', encoding = 'utf-8') as f:
    f.write(json.dumps(items, ensure_ascii=False))

# %% [markdown]
# Отсортируeм значения по полю ['age'] в убывающем порядке:

# %%
items = sorted(items, key = lambda x: x['age'], reverse = True)
print(items[0:5])
# Out:
# [{'name': 'Бетельгейзе 4405', 'constellation': 'Рак', 'spectral-class': 'T3R', 'radius': 437186814, 'rotation': '466.9 days', 'age': '5.99 billion years', 'distance': '2314469.01 million km', 'absolute-magnitude': '3.31 million km'}, {'name': 'Солнце 4319', 'constellation': 'Рыбы', 'spectral-class': 'S3Z', 'radius': 385699226, 'rotation': '130.52 days', 'age': '5.94 billion years', 'distance': '7446074.5 million km', 'absolute-magnitude': '6.44 million km'}, {'name': 'Альфа Центавра 4905', 'constellation': 'Овен', 'spectral-class': 'V0G', 'radius': 735551859, 'rotation': '437.64 days', 'age': '5.94 billion years', 'distance': '451697.27 million km', 'absolute-magnitude': '2.31 million km'}, {'name': 'Бетельгейзе 5036', 'constellation': 'Весы', 'spectral-class': 'J8S', 'radius': 370431577, 'rotation': '843.12 days', 'age': '5.93 billion years', 'distance': '1660203.44 million km', 'absolute-magnitude': '4.64 million km'}, {'name': 'Хадар 4722', 'constellation': 'Лев', 'spectral-class': 'F4R', 'radius': 112544367, 'rotation': '116.68 days', 'age': '5.86 billion years', 'distance': '4076680.69 million km', 'absolute-magnitude': '1.38 million km'}]

# %% [markdown]
# Выполним фильтрацию по полю ['constellation'] == 'Водолей':

# %%
filtered_items = []
for star in items:
    if star['constellation'] == 'Водолей':
        filtered_items.append(star)
print(filtered_items[0:5])
# Out:
# [{'name': 'Антарес 8500', 'constellation': 'Водолей', 'spectral-class': 'W2F', 'radius': 972065158, 'rotation': '256.04 days', 'age': '5.69 billion years', 'distance': '3071292.15 million km', 'absolute-magnitude': '9.83 million km'}, {'name': 'Ригель 7200', 'constellation': 'Водолей', 'spectral-class': 'M5F', 'radius': 299914890, 'rotation': '807.04 days', 'age': '5.61 billion years', 'distance': '9870507.28 million km', 'absolute-magnitude': '9.34 million km'}, {'name': 'Солнце 8751', 'constellation': 'Водолей', 'spectral-class': 'V3Y', 'radius': 800580547, 'rotation': '878.77 days', 'age': '5.54 billion years', 'distance': '4328837.22 million km', 'absolute-magnitude': '6.93 million km'}, {'name': 'Фомальгаут 5923', 'constellation': 'Водолей', 'spectral-class': 'E0Y', 'radius': 857248239, 'rotation': '75.06 days', 'age': '5.53 billion years', 'distance': '9718261.47 million km', 'absolute-magnitude': '4.16 million km'}, {'name': 'Хадар 3573', 'constellation': 'Водолей', 'spectral-class': 'G6T', 'radius': 426736818, 'rotation': '329.47 days', 'age': '5.46 billion years', 'distance': '8678689.43 million km', 'absolute-magnitude': '3.94 million km'}]

# %%
with open("result_filtered_63_3.json", "w", encoding = 'utf-8') as file:
    file.write(json.dumps(filtered_items, ensure_ascii=False))

# %% [markdown]
# для числового поля ['radius'] посчитаем статистические характеристики (сумма, мин/макс, среднее и т.д.)

# %%
stats_items = []
df = pd.DataFrame(items)
pd.set_option('display.float_format', '{:.1f}'.format)
stats = df['radius'].agg(['max', 'min', 'mean', 'median', 'std']).to_dict()
stats_items.append(stats)
print(stats_items)
# Out:
# [{'max': 996794584.0, 'min': 115514.0, 'mean': 507117069.358, 'median': 521078280.5, 'std': 291314251.5815782}]

# %% [markdown]
# для текстового поля ['name'] посчитайте частоту меток

# %%
text_items = []
text = [item['name'] for item in items]
f1 = collections.Counter(text)
